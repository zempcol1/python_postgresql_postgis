# %% [markdown]
# # Python with PostgreSQL & PostGIS
#
# <span>Note: Please always run the complete Jupyter Notebook from the beginning, as object names such as 'sql' and 'gdf' are reused in the code cells.</span>

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis

# %% [markdown]
# ## Create database connection

# %%
# Set up database connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Create Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test database connection
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT current_database();"))
        db_name = result.scalar()
        print("Current database:", db_name)
except Exception as e:
    print("Error connecting to the database:", e)

# Dispose the engine
engine.dispose()
# Out:
# Current database: osm_switzerland

# %% [markdown]
# ## List tables in database

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Open a connection
with engine.connect() as connection:

    # Execute the query
    result = connection.execute(text("""SELECT table_name
                                        FROM information_schema.tables
                                        WHERE table_schema = 'public';"""))
    
    # Fetch and print the results
    for row in result:
        print(row[0])

# Dispose the engine
engine.dispose()
# Out:
# geography_columns
# geometry_columns
# spatial_ref_sys
# planet_osm_roads
# planet_osm_line
# planet_osm_polygon
# planet_osm_point

# %% [markdown]
# ## Show columns and data types of a selected table

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Specify your table name
table_name = 'planet_osm_polygon'

# Query to get column information
query = f"""SELECT column_name, data_type 
        FROM information_schema.columns 
        WHERE table_name = '{table_name}'"""

# Execute the query and read the result into a DataFrame
df = pd.read_sql(query, engine)

# Dispose the engine
engine.dispose()

# Print the DataFrame
df
# Out:
#          column_name     data_type
# 0             osm_id        bigint
# 1             access          text
# 2     addr:housename          text
# 3        addr:street          text
# 4   addr:housenumber          text
# ..               ...           ...
# 68             width          text
# 69              wood          text
# 70           z_order       integer
# 71          way_area          real
# 72               way  USER-DEFINED
#
# [73 rows x 2 columns]

# %% [markdown]
# ## Query: Select buildings for which the full address is available in defined zip code areas

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Define SQL query 
sql = """SELECT
                p.osm_id,
                p."addr:street",
                p."addr:housenumber",
                p."addr:city",
                p."addr:postcode",
                p.building,
                st_transform(p.way, 4326) AS geom
        FROM
                public.planet_osm_polygon AS p
        WHERE
                p."addr:street" IS NOT NULL
                AND p."addr:housenumber" IS NOT NULL
                AND p."addr:city" IS NOT NULL
                AND p."addr:postcode" IN ('8001', '8002')"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf
# Out:
#          osm_id       addr:street addr:housenumber addr:city addr:postcode  \
# 0     157954139      Löwenstrasse               67    Zürich          8001
# 1     185748494     Predigerplatz               26    Zürich          8001
# 2     185748492     Predigerplatz               22    Zürich          8001
# 3     185748488     Predigerplatz               14    Zürich          8001
# 4     185748487     Predigerplatz               10    Zürich          8001
# ...         ...               ...              ...       ...           ...
# 2347   80338523      Löwenstrasse               10    Zürich          8001
# 2348  318684689  Nüschelerstrasse               36    Zürich          8001
# 2349  326259135     Uraniastrasse               32    Zürich          8001
# 2350   80338508     Uraniastrasse               34    Zürich          8001
# 2351   80340627     Uraniastrasse               33    Zürich          8001
#
#         building                                               geom
# 0     commercial  POLYGON ((8.53805 47.37717, 8.53808 47.37716, ...
# 1     apartments  POLYGON ((8.54549 47.37359, 8.54554 47.37353, ...
# 2            yes  POLYGON ((8.54543 47.37356, 8.54553 47.37345, ...
# 3     apartments  POLYGON ((8.5453 47.37352, 8.5454 47.3734, 8.5...
# 4     apartments  POLYGON ((8.54523 47.3735, 8.54532 47.37339, 8...
# ...          ...                                                ...
# 2347         yes  POLYGON ((8.53494 47.37345, 8.53498 47.37344, ...
# 2348         yes  POLYGON ((8.53521 47.37333, 8.53523 47.37333, ...
# 2349         yes  POLYGON ((8.53541 47.37349, 8.53555 47.37343, ...
# 2350         yes  POLYGON ((8.53534 47.37342, 8.53548 47.37336, ...
# 2351         yes  POLYGON ((8.53562 47.37321, 8.5357 47.37317, 8...
#
# [2352 rows x 7 columns]

# %% [markdown]
# ## Show selected features on map
#
# <span">Note the popup field in the map, which has been added to provide additional information about buildings.</span>
#
# <span">Example of alternative background maps (maptiles) are:</span>
# - <span">EsriWorldImagery</span>
# - <span">EsriWorldTopoMap</span>
# - <span">EsriWorldGrayCanvas</span>
# - <span">CartoDBDarkMatter</span>
# - <span">CartoDBPositron</span>

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=15,
               tiles='EsriWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='geojson',
    weight=0.5,
    fill_color='greenyellow',
    fillOpacity=0.8,
    popup=folium.GeoJsonPopup(fields=['addr:street',
                                      'addr:housenumber',
                                      'addr:city',
                                      'addr:postcode',
                                      'building'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00a5368567a62dca37196d398f0b2b86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00a5368567a62dca37196d398f0b2b86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00a5368567a62dca37196d398f0b2b86 = L.map(
#                 &quot;map_00a5368567a62dca37196d398f0b2b86&quot;,
#                 {
#                     center: [47.367113636217915, 8.537068173855975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69f8db030f8c235d6fbb7a2446dd5c3b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69f8db030f8c235d6fbb7a2446dd5c3b.addTo(map_00a5368567a62dca37196d398f0b2b86);
#
#
#
#         function geo_json_cf261012ffb97d76502bdf51ff22598c_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_cf261012ffb97d76502bdf51ff22598c = L.geoJson(null, {
#                 onEachFeature: geo_json_cf261012ffb97d76502bdf51ff22598c_onEachFeature,
#
#             ...{
#   &quot;weight&quot;: 0.5,
#   &quot;fillColor&quot;: &quot;greenyellow&quot;,
#   &quot;fillOpacity&quot;: 0.8,
# }
#         });
#
#         function geo_json_cf261012ffb97d76502bdf51ff22598c_add (data) {
#             geo_json_cf261012ffb97d76502bdf51ff22598c
#                 .addData(data);
#         }
#             geo_json_cf261012ffb97d76502bdf51ff22598c_add({&quot;bbox&quot;: [8.51801, 47.35034580008685, 8.550548200000001, 47.3801713000803], &quot;features&quot;: [{&quot;bbox&quot;: [8.5380523, 47.37709540008099, 8.5383014, 47.37725380008094], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.5380523, 47.37717080008097], [8.5380761, 47.37716000008097], [8.538219899999998, 47.37709540008099], [8.5383014, 47.37717840008096], [8.538133699999998, 47.37725380008094], [8.5380523, 47.37717080008097]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;67&quot;, &quot;addr:postcode&quot;: &quot;8001&quot;, &quot;addr:street&quot;: &quot;L\u00f6wenstrasse&quot;, &quot;building&quot;: &quot;commercial&quot;, &quot;osm_id&quot;: 157954139}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5454874, 47.373441000081776, 8.5456738, 47.37360410008176], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.5454874, 47.37358600008175], [8.5455371, 47.373533400081755], [8.5455451, 47.373533100081765], [8.5455961, 47.37347600008176], [8.545630099999999, 47.373441000081776], [8.5456738, 47.373457500081784], [8.5455474, 47.37360410008176], [8.5454874, 47.37358600008175]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;26&quot;, &quot;addr:postcode&quot;: &quot;8001&quot;, &quot;addr:street&quot;: &quot;Predigerplatz&quot;, &quot;building&quot;: &quot;apartments&quot;, &quot;osm_id&quot;: 185748494}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5454271, 47.373451000081786, 8.5455961, 47.37358600008175], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.5454271, 47.37356480008175], [8.545526399999998, 47.373451000081786], [8.5455961, 47.37347600008176], [8.5455451, 47.373533100081765], [8.5455371, 47.373533400081755], [8.5454874, 47.37358600008175], [8.5454271, 47.37356480008175]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;22&quot;, &quot;addr:postcode&quot;: &quot;8001&quot;, &quot;addr:street&quot;: &quot;Predigerplatz&quot;, &quot;building&quot;: &quot;yes&quot;, &quot;osm_id&quot;: 185748492}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5453032, 47.37340410008177, 8.5454568, 47.37353840008177], &quot;geometry&quot;: {&quot;coordinates&

# %% [markdown]
# ## Query: Select coffee stores

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)  

# Define SQL query
sql = """SELECT
            h.osm_id,
            h.shop,
            h.name,
            ST_Transform(h.way, 4326) AS geom
        FROM planet_osm_point h
        WHERE h.shop = 'coffee';"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf.head()
# Out:
#         osm_id    shop                name                      geom
# 0  11017970651  coffee  Vitudurum.com GmbH  POINT (8.75393 47.50449)
# 1   4841545900  coffee  Nespresso Boutique  POINT (8.59574 47.40825)
# 2  12023129318  coffee            Atinkana  POINT (8.59894 47.40057)
# 3  10967856734  coffee            Beanbank  POINT (8.53654 47.36939)
# 4   5297627699  coffee      Rent a Barista  POINT (8.53152 47.37352)

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=11, 
               tiles='EsriWorldTopoMap')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
    popup=folium.GeoJsonPopup(fields=['name', 'shop'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5ad49217fb646f5a037cd17d0589e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5ad49217fb646f5a037cd17d0589e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5ad49217fb646f5a037cd17d0589e44 = L.map(
#                 &quot;map_f5ad49217fb646f5a037cd17d0589e44&quot;,
#                 {
#                     center: [47.40736837819924, 8.589872403125],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ac24cfcb36136f02298cf194c1e1a2a = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Esri, DeLorme, NAVTEQ, TomTom, Intermap, iPC, USGS, FAO, NPS, NRCAN, GeoBase, Kadaster NL, Ordnance Survey, Esri Japan, METI, Esri China (Hong Kong), and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ac24cfcb36136f02298cf194c1e1a2a.addTo(map_f5ad49217fb646f5a037cd17d0589e44);
#
#
#
#         function geo_json_6b2ec00a1caed3ba30e4a52ed16c191d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6b2ec00a1caed3ba30e4a52ed16c191d = L.geoJson(null, {
#                 onEachFeature: geo_json_6b2ec00a1caed3ba30e4a52ed16c191d_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_6b2ec00a1caed3ba30e4a52ed16c191d_add (data) {
#             geo_json_6b2ec00a1caed3ba30e4a52ed16c191d
#                 .addData(data);
#         }
#             geo_json_6b2ec00a1caed3ba30e4a52ed16c191d_add({&quot;bbox&quot;: [8.386483599999998, 47.31128110009538, 8.7996489, 47.512114200050924], &quot;features&quot;: [{&quot;bbox&quot;: [8.7539295, 47.50449040005264, 8.7539295, 47.50449040005264], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7539295, 47.50449040005264], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Vitudurum.com GmbH&quot;, &quot;osm_id&quot;: 11017970651, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5957397, 47.408249200074096, 8.5957397, 47.408249200074096], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5957397, 47.408249200074096], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Nespresso Boutique&quot;, &quot;osm_id&quot;: 4841545900, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.598944799999998, 47.400574600075785, 8.598944799999998, 47.400574600075785], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.598944799999998, 47.400574600075785], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Atinkana&quot;, &quot;osm_id&quot;: 12023129318, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5365434, 47.36939410008266, 8.5365434, 47.36939410008266], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5365434, 47.36939410008266], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Beanbank&quot;, &quot;osm_id&quot;: 10967856734, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.531518100000001, 47.37351840008176, 8.531518100000001, 47.37351840008176], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.531518100000001, 47.37351840008176], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Rent a Barista&quot;, &quot;osm_id&quot;: 5297627699, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.487326700000002, 47.38833260007849, 8.487326700000002, 47.38833260007849], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.487326700000002, 47.38833260007849], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Tchibo&quot;, &quot;osm_id&quot;: 4838594338, &quot;shop&quot;: &quot;coffee&

# %% [markdown]
# ## Query: Select all supermarkets in a distance of 1000m around the central station in the city of Winterthur.
#
# <span>Note:</span>
#
# <span>For each supermarket, the distance to the central station in meters is calculated and stored as new column 'distance_meters'.</span>
#
# <span>In addition, a popup field was added to the map, allowing users to view detailed information about each selected feature when they click on it.</span>
#
# <span>The WGS84 (World Geodetic System 1984) coordinates in ST_MakePoint(LON, LAT) were derived from: https://tools.retorte.ch/map.</span>

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)  

# Define SQL query
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            ST_Distance(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates
                ST_SetSRID(ST_MakePoint(8.72397, 47.50031), 4326)::geography
            ) AS distance_meters,
            ST_TRANSFORM(p.way, 4326) AS geom
        FROM
            planet_osm_point AS p
        WHERE
            p.shop = 'supermarket'
            AND ST_DWithin(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates
                ST_SetSRID(ST_MakePoint(8.72397, 47.50031), 4326)::geography,
                1000
            )
        ORDER BY distance_meters;"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf.head()
# Out:
#        osm_id         shop       name  distance_meters  \
# 0   706203439  supermarket       Coop       159.883419
# 1  4109460421  supermarket  Asia Shop       162.391281
# 2  3831772784  supermarket     Migros       247.578208
# 3  7380954145  supermarket   Alnatura       256.838011
# 4  4095400190  supermarket       ALDI       274.275393
#
#                        geom
# 0  POINT (8.72594 47.50085)
# 1  POINT (8.72208 47.50101)
# 2  POINT (8.72115 47.49916)
# 3  POINT (8.72074 47.49958)
# 4   POINT (8.72476 47.4979)

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='ESRIWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
    popup=folium.GeoJsonPopup(fields=['name', 'distance_meters'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6117c1fdffcc5d5aae376a095e5b26ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6117c1fdffcc5d5aae376a095e5b26ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6117c1fdffcc5d5aae376a095e5b26ce = L.map(
#                 &quot;map_6117c1fdffcc5d5aae376a095e5b26ce&quot;,
#                 {
#                     center: [47.50009464550818, 8.724396472727271],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c18ebe63e1f2a4749403250a098d83bb = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c18ebe63e1f2a4749403250a098d83bb.addTo(map_6117c1fdffcc5d5aae376a095e5b26ce);
#
#
#
#         function geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5 = L.geoJson(null, {
#                 onEachFeature: geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5_add (data) {
#             geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5
#                 .addData(data);
#         }
#             geo_json_cb9e7760fc41ea72e8b8c0d1a926abf5_add({&quot;bbox&quot;: [8.719137299999998, 47.497901300054146, 8.732985899999997, 47.50441840005266], &quot;features&quot;: [{&quot;bbox&quot;: [8.725937799999999, 47.500848300053455, 8.725937799999999, 47.500848300053455], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.725937799999999, 47.500848300053455], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 159.88341889, &quot;name&quot;: &quot;Coop&quot;, &quot;osm_id&quot;: 706203439, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.722078199999999, 47.50100990005341, 8.722078199999999, 47.50100990005341], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.722078199999999, 47.50100990005341], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 162.39128099, &quot;name&quot;: &quot;Asia Shop&quot;, &quot;osm_id&quot;: 4109460421, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.721153199999998, 47.499163300053844, 8.721153199999998, 47.499163300053844], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.721153199999998, 47.499163300053844], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 247.57820785, &quot;name&quot;: &quot;Migros&quot;, &quot;osm_id&quot;: 3831772784, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7207353, 47.49958100005376, 8.7207353, 47.49958100005376], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7207353, 47.49958100005376], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 256.83801124, &quot;name&quot;: &quot;Alnatura&quot;, &quot;osm_id&quot;: 7380954145, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7247563, 47.497901300054146, 8.7247563, 47.497901300054146], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7247563, 47.497901300054146], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 274.27539294, &quot;name&quot;: &quot;ALDI&quot;, &quot;osm_id&quot;: 4095400190, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7201688, 47.500732100053476, 8.7201688, 47.500732100053476], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7201688, 47.500732100053476], &quot;type&quot;: &quot;Point&quot;}, &

# %% [markdown]
# ## Query: Select all roads classified as 'motorway' and create a 5000m buffer around these roads.

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Define SQL query (major roads)
sql = """-- Create buffer around major roads
        SELECT 
            1 as group_id,
            ST_TRANSFORM(ST_UNION(ST_Buffer(p.way::geometry, 2000)), 4326) AS geom
        FROM public.planet_osm_roads AS p
        WHERE
            highway = 'motorway';"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine, geom_col='geom')

# Dispose the engine
engine.dispose()

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=11, 
               tiles='EsriWorldTopoMap')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a382b0c3e02477acb0c9f50735edb3e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a382b0c3e02477acb0c9f50735edb3e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a382b0c3e02477acb0c9f50735edb3e1 = L.map(
#                 &quot;map_a382b0c3e02477acb0c9f50735edb3e1&quot;,
#                 {
#                     center: [47.39309738971501, 8.596294437941214],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48b39019255eaa068e5d69fc7e6f0c2f = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Esri, DeLorme, NAVTEQ, TomTom, Intermap, iPC, USGS, FAO, NPS, NRCAN, GeoBase, Kadaster NL, Ordnance Survey, Esri Japan, METI, Esri China (Hong Kong), and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48b39019255eaa068e5d69fc7e6f0c2f.addTo(map_a382b0c3e02477acb0c9f50735edb3e1);
#
#
#
#         function geo_json_922cdcc551f58ce6442ddf0307d48a26_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_922cdcc551f58ce6442ddf0307d48a26 = L.geoJson(null, {
#                 onEachFeature: geo_json_922cdcc551f58ce6442ddf0307d48a26_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_922cdcc551f58ce6442ddf0307d48a26_add (data) {
#             geo_json_922cdcc551f58ce6442ddf0307d48a26
#                 .addData(data);
#         }
#             geo_json_922cdcc551f58ce6442ddf0307d48a26_add({&quot;bbox&quot;: [8.345323237611277, 47.18402193587036, 8.921217168663748, 47.57964429275077], &quot;features&quot;: [{&quot;bbox&quot;: [8.345323237611277, 47.18402193587036, 8.921217168663748, 47.57964429275077], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[8.355513522483292, 47.41963416956454], [8.355102612682824, 47.419793501738724], [8.354690212682826, 47.41995833450662], [8.354563433690718, 47.42000948338298], [8.354345592011132, 47.420098194080516], [8.354310687638927, 47.42011173576788], [8.351441739935188, 47.42149402363239], [8.349026480969997, 47.42322840041391], [8.347157727790888, 47.42524818388046], [8.345907295534527, 47.42747572685834], [8.345323237611277, 47.42982540543645], [8.345427999039583, 47.432206912594054], [8.346217553896505, 47.43452873020023], [8.347661560031682, 47.436701645721975], [8.349704525099144, 47.438642178538956], [8.35226793909706, 47.440275784508884], [8.355253291463066, 47.44153971617435], [8.358545856779942, 47.44238542937727], [8.362019103609054, 47.442780444516885], [8.365539557022577, 47.4427095915739], [8.368971927970124, 47.44217559153442], [8.372184312361075, 47.44119895210596], [8.372384112361074, 47.44112146763178], [8.372711866309281, 47.44099122569382], [8.373029332080725, 47.440861996782516], [8.373174284407256, 47.44080408363743], [8.373285479395477, 47.44076229155212], [8.373805958418476, 47.44057577753121], [8.375595748646461, 47.43996161016565], [8.37572375503359, 47.43991724778259], [8.375807312371816, 47.43988800360882], [8.377762540301052, 47.43935355600799], [8.379491325973044, 47.43874146973123], [8.381851911742922, 47.437919766407596], [8.381872728654784, 47.43791067238571], [8.381895743415129, 47.43790445727113], [8.386274883296634, 47.436369773290856], [8.387609135947624, 47.43591033061377], [8.38791864857441, 47.43580723059493], [8.387960223324674, 47.435789764959445], [8.388005942597939, 47.435777953325676], [8.388364716818845, 47.43565680404561], [8.388818364146847, 47.43550810015578], [8.389160026762521, 47.435403115768814], [8.38927926833769, 47.43536642662678], [8.389985004082718, 47.43516392392742], [8.390392319539865, 47.43505940861359], [8.390695991354573, 47.43498807780738], [8.391032844535388, 47.43491985186101], [8.391639609101304, 47.43480787380502], [8.391926880651177, 47.43475745550428], [8.391952772530647, 47.43475351999394], [8.3920209811178, 47.43474471335307], [8.392587865827322, 47.43468052798633], [8.393016100011309, 47.434638654603546], [8.393264394557313, 47.434616430351234], [8.39334267228433, 47.43461101288875], [8.39364029002857, 47.43459050364938], [8.3942194523279, 47.43455317329653], [8.394349614536587, 47.43453595018385], [8.39448223489942, 47.43453491581401], [8.394785932761966, 47.434512288239326], [8.39521542863151, 47.43448031754207], [8.397371734343139, 47.4343547045678], [8.39755548115756, 47.43434335734704], [8.399020081157559, 47.43424777931882], [8.39929470541316, 47.43422841579986], [8.400606305413161, 47.434129038608354], [8.401153921615261, 47.434081773667366], [8.401380921615262, 47.43405977869576], [8.401522980938456, 47.434045621858154], [8.402944280938456, 47.433900055097816]

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-09-24 17:12:28
# Python Version: 3.12.1
# -----------------------------------
